# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushmithaa-G/Python-EDA-Project-NETFLIX/blob/main/Python_EDA_Project_NETFLIX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python EDA Project - NETFLIX**

# %% [markdown]
# **This dataset consists of tv shows and movies available on Netflix as of 2021. The dataset is collected from Flixable which is a third-party Netflix search engine. It will be interesting to explore what all insights can be obtained from the same dataset.**

# %% [markdown]
# **Explore and analyze the data to discover key findings pertaining to tv shows and movies available on Netflix.**

# %%
#import pandas and numpy libraries
import pandas as pd
import numpy as np
# import matplotlib.pyplot and seaborn for data visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"/content/drive/MyDrive/Netflix Data.csv")

# %%
data
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
# 5850   tm180542                Once Upon a Time in America  MOVIE
# 5851  tm1033635                           Sisters on Track  MOVIE
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %% [markdown]
# **Getting some basic information about the dataset**

# %% [markdown]
# **1. head()**

# %%
data.head()                               #to show top 5 records of the dataset
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# ...

# %% [markdown]
# **2. tail()**

# %%
data.tail()                            #to show bottom 5 records of the dataset
# Out:
#              id                                      title   type  \
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
# 5850   tm180542                Once Upon a Time in America  MOVIE
# 5851  tm1033635                           Sisters on Track  MOVIE
#
#                                             description  release_year  \
# 5847  A controversial TV host and comedian who has b...          2021
# 5848  Jamie Foxx, David Alan Grier and more from the...          2021
# 5849  With winter behind them, Bheem and his townspe...          2021
# 5850  A former Prohibition-era Jewish gangster retur...          1984
# 5851  Three track star sisters face obstacles in lif...          2021
#
#      age_certification  runtime                             genres  \
# 5847               NaN       90                         ['comedy']
# ...

# %% [markdown]
# **3. shape**

# %%
data.shape                              #to show no. of rows and columns
# Out:
# (5852, 15)

# %%
data.shape[0]                        # returns the count of rows
# Out:
# 5852

# %%
data.shape[1]                        #returns the count of column
# Out:
# 15

# %% [markdown]
# **4. size**

# %%
data.size                           #to show total values(elements)in the dataset
# Out:
# 87780

# %% [markdown]
# **5. column**

# %%
data.columns                        #to show each column name
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %% [markdown]
# **6. dtypes**

# %%
data.dtypes                     #to show data type of each column
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %% [markdown]
# **7. info()**

# %%
data.info()                         #to show index, column, data-type of each column memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5852 entries, 0 to 5851
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5852 non-null   object
#  1   title                 5851 non-null   object
#  2   type                  5852 non-null   object
#  3   description           5834 non-null   object
#  4   release_year          5852 non-null   int64
#  5   age_certification     3233 non-null   object
#  6   runtime               5852 non-null   int64
#  7   genres                5852 non-null   object
#  8   production_countries  5852 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5449 non-null   object
#  11  imdb_score            5370 non-null   float64
#  12  imdb_votes            5354 non-null   float64
#  13  tmdb_popularity       5761 non-null   float64
#  14  tmdb_score            5541 non-null   float64
# ...

# %% [markdown]
# **8. isnull()**

# %%
data.isnull().sum()           #returns the count of null values in each column
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3746
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %% [markdown]
# **9. describe()**

# %%
data.describe()          #returns the numerical columns and its operations
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   5852.000000  5852.000000  2106.000000  5370.000000  5.354000e+03
# mean    2016.412338    76.902768     2.162868     6.511061  2.349523e+04
# std        6.949731    39.005093     2.689041     1.163906  9.590429e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2016.000000    44.000000     1.000000     5.800000  5.162500e+02
# 50%     2018.000000    83.000000     1.000000     6.600000  2.233500e+03
# 75%     2020.000000   104.250000     2.000000     7.300000  9.498000e+03
# max     2022.000000   240.000000    42.000000     9.600000  2.294231e+06
#
#        tmdb_popularity   tmdb_score
# count      5761.000000  5541.000000
# mean         22.636380     6.829517
# std          81.666369     1.170389
# min           0.009442     0.500000
# 25%           2.730000     6.100000
# 50%           6.822000     6.900000
# 75%          16.591000     7.542000
# ...

# %% [markdown]
# **Task 1 : Checking if there is any duplicate records, and if yes then deleting the duplicate records permanently**

# %% [markdown]
# **duplicate()**

# %%
data.shape
# Out:
# (5852, 15)

# %%
data[data.duplicated()]            #to check row wise and detect the duplicate rows
# Out:
#              id                        title   type  \
# 5850   tm180542  Once Upon a Time in America  MOVIE
# 5851  tm1033635             Sisters on Track  MOVIE
#
#                                             description  release_year  \
# 5850  A former Prohibition-era Jewish gangster retur...          1984
# 5851  Three track star sisters face obstacles in lif...          2021
#
#      age_certification  runtime                          genres  \
# 5850                 R      139  ['crime', 'drama', 'european']
# 5851                PG       96      ['documentation', 'sport']
#
#      production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 5850         ['US', 'IT']      NaN  tt0087843         8.3    345714.0
# 5851               ['US']      NaN  tt9337574         5.8       199.0
#
#       tmdb_popularity  tmdb_score
# 5850           28.937       8.453
# 5851            7.433       7.100

# %%
data.drop_duplicates()         #to delete duplicate rows[but the changes are not permanent]
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
data.drop_duplicates(inplace = True)                   #to delete duplicate rows permanently

# %%
data.shape
# Out:
# (5850, 15)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %% [markdown]
# **Task 1 : Checking if there is any NULL value present in any column? Show in heat map**

# %% [markdown]
# **isnull()**

# %%
data.isnull()                        #to show where null value is present
# Out:
#          id  title   type  description  release_year  age_certification  \
# 0     False  False  False        False         False              False
# 1     False  False  False        False         False              False
# 2     False  False  False        False         False              False
# 3     False  False  False        False         False              False
# 4     False  False  False        False         False               True
# ...     ...    ...    ...          ...           ...                ...
# 5845  False  False  False        False         False               True
# 5846  False  False  False        False         False               True
# 5847  False  False  False        False         False               True
# 5848  False  False  False        False         False              False
# 5849  False  False  False        False         False               True
#
#       runtime  genres  production_countries  seasons  imdb_id  imdb_score  \
# ...

# %%
data.isnull().sum()                            #to show count of null value in each column
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %% [markdown]
# **SEABORN LIBRARY(HEAT MAP)**

# %%
sns.heatmap(data.isnull())            #using heat map to show null value count
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Q1. For '1000 Miles from Christmas', what is the ID and what is the Genres of this movie?**

# %% [markdown]
# **isin()**

# %%
data[data['title'].isin(['1000 Miles from Christmas'])]        #to show all records of a particular item in any column
# Out:
#              id                      title   type  \
# 5654  tm1013111  1000 Miles from Christmas  MOVIE
#
#                                             description  release_year  \
# 5654  A Christmas tale, a romantic comedy and the st...          2021
#
#      age_certification  runtime                                      genres  \
# 5654               NaN      102  ['comedy', 'romance', 'fantasy', 'family']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 5654               ['ES']      NaN  tt13782052         5.7      1502.0
#
#       tmdb_popularity  tmdb_score
# 5654           16.617         6.3

# %% [markdown]
# **Q2. In which year highest number of the TV shows and Movies were realised? Show with the bar graph.**

# %% [markdown]
# **value_counts()**

# %%
data['release_year'].value_counts()                  #it counts the occurrence of all individual year in r_year column
# Out:
# 2019    836
# 2020    814
# 2021    787
# 2018    773
# 2017    563
#        ...
# 1960      1
# 1974      1
# 1959      1
# 1978      1
# 1945      1
# Name: release_year, Length: 63, dtype: int64

# %% [markdown]
# **Bar Graph**

# %%
data['release_year'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Q3. How many movies and TV shows are there in the dataset? Show with bar graph.**

# %% [markdown]
# **groupby()**

# %%
data.groupby('type').type.count()                #to group all unique item of a column and show their count
# Out:
# type
# MOVIE    3744
# SHOW     2106
# Name: type, dtype: int64

# %% [markdown]
# **countplot()**

# %%
sns.countplot(data['type'])         #to show the count of all unique values of any column in the form of bar graph
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# **Q4. Show all the movies that were released in the year 2022.**

# %% [markdown]
# **Filtering**

# %%
data[(data['type'] == 'MOVIE') & (data['release_year'] == 2022)]
# Out:
#              id                                    title   type  \
# 4692  tm1080445                             The Gray Man  MOVIE
# 4694   tm463762                                      RRR  MOVIE
# 4696   tm852360                     The Man from Toronto  MOVIE
# 4697  tm1170388                               Persuasion  MOVIE
# 4698  tm1126268                                   Hustle  MOVIE
# ...         ...                                      ...    ...
# 5803  tm1204412               Let's Tie the Knot, Honey!  MOVIE
# 5805  tm1201341  Rodrigo Sant'anna: I'm Here, I'm Queer!  MOVIE
# 5811  tm1183575           Celeb Five: Behind the Curtain  MOVIE
# 5839  tm1165179                              Kongsi Raya  MOVIE
# 5840  tm1216735                          Sun of the Soil  MOVIE
#
#                                             description  release_year  \
# 4692  When a shadowy CIA agent uncovers damning agen...          2022
# ...

# %% [markdown]
# **Q5. Show only the title of the TV shows that were produced in India only.**

# %% [markdown]
# **Filterning**

# %%
data[ (data['type'] == 'SHOW') & (data['production_countries'] == "['IN']" )]
# Out:
#             id                                  title  type  \
# 504    ts18653                           Chhota Bheem  SHOW
# 629   ts124246                            Mighty Raju  SHOW
# 994   ts122290                          Dharmakshetra  SHOW
# 1033  ts121189        Raja, Rasoi Aur Anya Kahaniyaan  SHOW
# 1538   ts84398                          Little Things  SHOW
# 1555   ts43258         Stories by Rabindranath Tagore  SHOW
# 2118   ts80959                           Sacred Games  SHOW
# 2192   ts82268                                  GHOUL  SHOW
# 2335   ts85822                          Selection Day  SHOW
# 2568   ts74765                   Daughters of Destiny  SHOW
# 2997  ts229123                         Little Singham  SHOW
# 3172  ts235672                                    She  SHOW
# 3500   ts90621                           Kota Factory  SHOW
# 3553   ts89028                            Delhi Crime  SHOW
# 3603  ts223659           Jamtara – Sabka Number Ayega  SHOW
# ...

# %%
data[ (data['type'] == 'SHOW') & (data['production_countries'] == "['IN']" )] ['title']   #to show only the titles of tv show produced in India
# Out:
# 504                              Chhota Bheem
# 629                               Mighty Raju
# 994                             Dharmakshetra
# 1033          Raja, Rasoi Aur Anya Kahaniyaan
# 1538                            Little Things
# 1555           Stories by Rabindranath Tagore
# 2118                             Sacred Games
# 2192                                    GHOUL
# 2335                            Selection Day
# 2568                     Daughters of Destiny
# 2997                           Little Singham
# 3172                                      She
# 3500                             Kota Factory
# 3553                              Delhi Crime
# 3603             Jamtara – Sabka Number Ayega
# 3660                               Typewriter
# 3694                                   Betaal
# 3824                          Paava Kadhaigal
# 3829                            Masaba Masaba
# 3906                               Mismatched
# ...

# %% [markdown]
# **Q6. Show top 10 Movies that has released more than once.**

# %%
data['title'].value_counts().head(10)
# Out:
# The Gift                     3
# Connected                    3
# Fearless                     2
# A Nightmare on Elm Street    2
# A Lion in the House          2
# Monster                      2
# Time Out                     2
# Skylines                     2
# Whispers                     2
# The Motive                   2
# Name: title, dtype: int64

# %% [markdown]
# **Q7. Show top 10 Movies that has highest Tmdb score.**

# %%
top_movies = data[data['type'] == 'MOVIE'].sort_values('tmdb_score', ascending=False).head(10)
print(top_movies[['title', 'tmdb_score']])
# Out:
#                                                   title  tmdb_score
# 5848          Dad Stop Embarrassing Me - The Afterparty        10.0
# 1613        Thomas & Friends: Full Steam To The Rescue!        10.0
# 4612                                  Uncle Naji in UAE        10.0
# 5013  Like A Rolling Stone: The Life & Times of Ben ...        10.0
# 4289                               True: Friendship Day        10.0
# 5181                                   Civil: Ben Crump        10.0
# 2813  Motu Patlu Kung Fu Kings 4 The Challenge of Ku...        10.0
# 5352  Thomas & Friends: All Engines Go - Race for th...        10.0
# 4579  Motu Patlu the Superheroes – Super Villains fr...        10.0
# 2935                             Three Words to Forever        10.0

# %% [markdown]
# **Q8. Show all the records where "catergory is movie and genres is comedies" or "country is United States".**

# %% [markdown]
# **Filtering (AND, OR Operations)**

# %%
data[ (data['type'] == 'MOVIE') & (data['genres'] == "['comedy']") | (data['production_countries'] == "['US']")]
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 6       tm70993                              Life of Brian  MOVIE
# 7       tm14873                                Dirty Harry  MOVIE
# ...         ...                                        ...    ...
# 5837  tm1040816                Momshies! Your Soul is Mine  MOVIE
# 5839  tm1165179                                Kongsi Raya  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %% [markdown]
# **Q9. In how many Tv Shows or Movies, genres is Thriller?**

# %% [markdown]
# **filtering**

# %%
data[ data['genres'] == 'thriller' ]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %% [markdown]
# **str.contains()**

# %%
data[ data['genres'].str.contains('thriller') ]
# Out:
#              id           title   type  \
# 2      tm154986     Deliverance  MOVIE
# 7       tm14873     Dirty Harry  MOVIE
# 23     tm204541     Dark Waters  MOVIE
# 25     tm356209       Singapore  MOVIE
# 29     tm336403     Khoon Khoon  MOVIE
# ...         ...             ...    ...
# 5759  tm1091823         Boomika  MOVIE
# 5767  tm1159298            Erax  MOVIE
# 5770  tm1098060  Shadow Parties  MOVIE
# 5807  tm1011248          30-Mar  MOVIE
# 5821  tm1110241          Kaaval  MOVIE
#
#                                             description  release_year  \
# 2     Intent on seeing the Cahulawassee River before...          1972
# 7     When a madman dubbed 'Scorpio' terrorizes San ...          1971
# 23    Ragab, a poor sailor, returns home to Alexandr...          1956
# 25    When his employee disappears in Singapore, Shy...          1960
# 29    As a crazed killer blazes a trail of blood thr...          1973
# ...

# %% [markdown]
# **Q10. What are the different age certification defined by Netflix?**

# %% [markdown]
# **nunique()**

# %%
data['age_certification'].nunique()            #to show number of data that are unique
# Out:
# 11

# %% [markdown]
# **unique()**

# %%
data['age_certification'].unique()             #to show all the different unique value of  age certification
# Out:
# array(['TV-MA', 'R', 'PG', nan, 'TV-14', 'PG-13', 'TV-PG', 'TV-Y', 'TV-G',
#        'TV-Y7', 'G', 'NC-17'], dtype=object)

# %% [markdown]
# **Q11. How many TV shows got TV-14 age certification which is produced in Great Britain?**

# %%
data[ (data['type'] == 'SHOW') & (data['age_certification'] == 'TV-14') & (data['production_countries'] == "['GB']") ]
# Out:
#             id                                       title  type  \
# 5      ts22164                Monty Python's Flying Circus  SHOW
# 236    ts20573                                The IT Crowd  SHOW
# 320    ts24028                                  Still Game  SHOW
# 657    ts27680                       Last Tango in Halifax  SHOW
# 686    ts18551                                      Cuckoo  SHOW
# 1182   ts41289                                     Flowers  SHOW
# 1345   ts37896                                  Conspiracy  SHOW
# 1442   ts87465             Witch Hunt: A Century of Murder  SHOW
# 1821   ts79926                   James Acaster: Repertoire  SHOW
# 1994   ts79020                     Hitler's Circle of Evil  SHOW
# 2110   ts75981                  The Royal House of Windsor  SHOW
# 2289   ts80059                    Trump: An American Dream  SHOW
# 2574   ts75887  Paul Hollywood's Big Continental Road Trip  SHOW
# ...

# %% [markdown]
# **Q12. How many Movie got R rating after year 2018?**

# %%
data[ (data['type'] == 'MOVIE') & (data['age_certification'] =='R') &  (data['release_year'] > 2018)]
# Out:
#              id                             title   type  \
# 3045   tm441050                     The Gentlemen  MOVIE
# 3072   tm681578                        The Rental  MOVIE
# 3075   tm369594     I'm Thinking of Ending Things  MOVIE
# 3076   tm244149                      The Irishman  MOVIE
# 3082   tm496322                        Extraction  MOVIE
# ...         ...                               ...    ...
# 5747  tm1150727    Kapil Sharma: I'm Not Done Yet  MOVIE
# 5758  tm1120766                            Angèle  MOVIE
# 5789  tm1019084  Ginny & Georgia - The Afterparty  MOVIE
# 5798  tm1099320  Convergence: Courage in a Crisis  MOVIE
# 5800   tm982470                       Stuck Apart  MOVIE
#
#                                             description  release_year  \
# 3045  American expat Mickey Pearson has built a high...          2019
# 3072  Two couples rent a vacation home for what shou...          2020
# ...

# %% [markdown]
# **Q13. What is the maximum duration of a Movie/show on Netflix?**

# %%
data.runtime.unique()
# Out:
# array([ 51, 114, 109,  91, 150,  30,  94, 102, 110, 104, 158, 117,  78,
#        115,  77,  97, 133, 129, 161, 186, 146, 100, 120,  74,  43, 124,
#        131, 162, 142,  93, 135, 141,  24, 145, 139,  96, 119,  10,  23,
#         26, 105,  90,  84, 116,  14, 123,  50,  87, 144,  81, 106, 174,
#         72, 172,  80, 148, 170, 159, 125, 160, 151, 108,  48,  44, 127,
#         22, 156, 103,  40, 194,  25, 107, 111,  46, 118, 191, 128,  28,
#         89, 136, 112,  18,  21,  19,  45,   9, 185,  63, 206, 163,  75,
#         49,  56, 175, 177,  88, 165,  58, 137,  61, 149,  60,  55, 126,
#         57,  95,  42, 196, 101, 140,  92,  83,  47,  99, 143,  15, 121,
#         98,  29,  82, 113,   7,  27, 224,  11, 208,  86,  36,  64,  17,
#         76, 138, 210,  32, 214,  20, 189,  13, 157,  73, 166, 184, 225,
#        155,  85,   3, 167,  31, 169, 179,  67, 190,   0, 132, 192, 122,
#        130,  59, 134, 182, 153, 173,  69,  37,  16,  65,  54,  53,  41,
# ...

# %%
val = data.runtime.max()

# %%
val
# Out:
# 240

# %%
max_runtime = data[data['runtime'] == val][['title', 'runtime']]

# %%
max_runtime
# Out:
#               title  runtime
# 923  Bonnie & Clyde      240

# %% [markdown]
# **Q14. How can we sort dataset by release year?**

# %% [markdown]
# **sort**

# %%
data.sort_values(by = 'release_year')
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 22      tm19608                      The Blazing Sun  MOVIE
# 13      tm16479                      White Christmas  MOVIE
# 23     tm204541                          Dark Waters  MOVIE
# 14     tm135083                        Cairo Station  MOVIE
# ...         ...                                  ...    ...
# 5133  tm1120902                        The Privilege  MOVIE
# 5559  tm1196455  The Photographer: Murder in Pinamar  MOVIE
# 4932   ts330347                      Cracow Monsters   SHOW
# 4924  tm1180610                     The Wrath of God  MOVIE
# 4957   ts304310                   No Regrets In Life   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 22    A rich landlord floods and destroys a village ...          1954
# ...

# %%
data.sort_values(by = 'release_year', ascending = False)
# Out:
#              id                                     title   type  \
# 4995  tm1207094  Pete Davidson Presents: The Best Friends  MOVIE
# 5623  tm1173806                               Night Drive  MOVIE
# 4991  tm1166020                              The Takedown  MOVIE
# 4989   ts349921       That’s My Time with David Letterman   SHOW
# 4988   ts329700         Life After Death with Tyler Henry   SHOW
# ...         ...                                       ...    ...
# 14     tm135083                             Cairo Station  MOVIE
# 23     tm204541                               Dark Waters  MOVIE
# 22      tm19608                           The Blazing Sun  MOVIE
# 13      tm16479                           White Christmas  MOVIE
# 0      ts300399       Five Came Back: The Reference Films   SHOW
#
#                                             description  release_year  \
# 4995  Pete Davidson jokes about rumors, free plane r...          2022
# ...

# %% [markdown]
# **Q15. Find all the instances where:**

# %% [markdown]
# **type is Movie AND genres is drama  OR type is Tv Show AND genres is horror**

# %%
data[ (data['type'] == 'MOVIE') & (data['genres'] == "['drama']")]
# Out:
#              id                       title   type  \
# 17      tm14350            Alexandria… Why?  MOVIE
# 18      tm81728                    The Land  MOVIE
# 27     tm200475           Beirut, Oh Beirut  MOVIE
# 50     tm142895                  Lean On Me  MOVIE
# 70     tm137013        The Ryan White Story  MOVIE
# ...         ...                         ...    ...
# 5804  tm1049317             Upcoming Summer  MOVIE
# 5822   tm993616  The Tambour of Retribution  MOVIE
# 5823  tm1099342             Devdas Brothers  MOVIE
# 5834  tm1091956              A Faraway Land  MOVIE
# 5846   tm898842                 C/O Kaadhal  MOVIE
#
#                                             description  release_year  \
# 17    Set against the panoramic backdrop of war-torn...          1979
# 18    Set in 1933, the mayor informs the peasants th...          1969
# 27    In the aftermath of the 1967 defeat, four youn...          1975
# ...

# %%
data[ (data['type'] == 'SHOW') & (data['genres'] == "['horror']")]
# Out:
#             id             title  type  \
# 5670  ts296581  The Mystic River  SHOW
#
#                                             description  release_year  \
# 5670  As pregnant women vanish in a remote Nigerian ...          2021
#
#      age_certification  runtime      genres production_countries  seasons  \
# 5670             TV-14       40  ['horror']               ['US']      1.0
#
#          imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 5670  tt15134080         5.8         5.0            1.441         NaN

# %%
data[ (data['type'] == 'MOVIE') & (data['genres'] == "['drama']") | (data['type'] == 'SHOW') & (data['genres'] == "['horror']") ]
# Out:
#              id                       title   type  \
# 17      tm14350            Alexandria… Why?  MOVIE
# 18      tm81728                    The Land  MOVIE
# 27     tm200475           Beirut, Oh Beirut  MOVIE
# 50     tm142895                  Lean On Me  MOVIE
# 70     tm137013        The Ryan White Story  MOVIE
# ...         ...                         ...    ...
# 5804  tm1049317             Upcoming Summer  MOVIE
# 5822   tm993616  The Tambour of Retribution  MOVIE
# 5823  tm1099342             Devdas Brothers  MOVIE
# 5834  tm1091956              A Faraway Land  MOVIE
# 5846   tm898842                 C/O Kaadhal  MOVIE
#
#                                             description  release_year  \
# 17    Set against the panoramic backdrop of war-torn...          1979
# 18    Set in 1933, the mayor informs the peasants th...          1969
# 27    In the aftermath of the 1967 defeat, four youn...          1975
# ...
